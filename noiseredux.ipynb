# %%
# !pip install speechbrain
# !pip install pydub

# %%
import librosa
import librosa.display

# %%
from speechbrain.inference.separation import SepformerSeparation as separator
import torchaudio

model = separator.from_hparams(source="speechbrain/sepformer-dns4-16k-enhancement", savedir='pretrained_models/sepformer-dns4-16k-enhancement')

est_sources = model.separate_file(path='/content/noisy_audio_file.wav')

torchaudio.save("enhanced_dns4-16k.wav", est_sources[:, :, 0].detach().cpu(), 16000)
# Out:
# hyperparams.yaml:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# encoder.ckpt:   0%|          | 0.00/17.3k [00:00<?, ?B/s]
# masknet.ckpt:   0%|          | 0.00/113M [00:00<?, ?B/s]
# decoder.ckpt:   0%|          | 0.00/17.2k [00:00<?, ?B/s]
# Resampling the audio from 32000 Hz to 16000 Hz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-fbfb0848d8e0> in <cell line: 7>()
#       5
#       6 # for custom file, change path
# ----> 7 est_sources = model.separate_file(path='/content/noisy_audio_file.wav')
#       8
#       9 torchaudio.save("enhanced_dns4-16k.wav", est_sources[:, :, 0].detach().cpu(), 16000)
#
# /usr/local/lib/python3.10/dist-packages/speechbrain/inference/separation.py in separate_file(self, path, savedir)
#     115             batch = tf(batch)
#     116
# --> 117         est_sources = self.separate_batch(batch)
#     118         est_sources = (
# ...

# %%
from pydub import AudioSegment
audio = AudioSegment.from_file("/content/enhanced_dns4-16k.wav")
audio
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
from pydub import AudioSegment
audio = AudioSegment.from_file("/content/noisy_audio_file.wav")
audio
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
audio_file = '/content/noisy_audio_file.wav'
y, sr = librosa.load(audio_file, sr=None)
librosa.display.waveshow(y, sr=sr)

# %%
audio_file = '/content/enhanced_dns4-16k.wav'
y, sr = librosa.load(audio_file, sr=None)
librosa.display.waveshow(y, sr=sr)
